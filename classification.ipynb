# %%
import re, string, unicodedata
import ast

import pandas as pd
import numpy as np

import gensim.downloader as api
from gensim.models.word2vec import Word2Vec

from gensim.test.utils import get_tmpfile
from gensim.models import KeyedVectors

from pathlib import Path

# %% [markdown]
# ## Load Data

# %%
data = pd.read_csv('csv/preprocessed_short_data_eclipse2017.csv')
data
# Out:
#        id resolution                                         short_desc  \
# 0       1       FIXE      ['usability', 'issue', 'external', 'editors']
# 1       2       FIXE  ['open', 'repository', 'resources', 'doesnt', ...
# 2       7       WONT  ['team', 'api', 'movecopy', 'semantics', 'pres...
# 3      10       FIXE            ['api', 'vcm', 'event', 'notification']
# 4      20       FIXE                              ['workspace', 'file']
# ..    ...        ...                                                ...
# 992  6454       FIXE    ['option', 'show', 'package', 'hierarchically']
# 993  6455       DUPL           ['npe', 'kill', 'javaindexer', 'thread']
# 994  6457       FIXE  ['rename', 'project', 'change', 'project', 'lo...
# 995  6460       DUPL     ['find', 'dialog', 'box', 'obscure', 'result']
# 996  6465       FIXE     ['code', 'assist', 'work', 'front', 'comment']
#
#               dup_list  root_id  disc_id  \
# 0                [183]      1.0      1.0
# 1    [94, 9779, 15392]      2.0      2.0
# 2              [42962]      7.0      7.0
# 3             [121067]     10.0     10.0
# 4                 [40]     20.0     20.0
# ..                 ...      ...      ...
# 992     [10029, 24425]   6454.0   6454.0
# 993                NaN  15262.0   6455.0
# 994             [8445]   6457.0   6457.0
# 995                NaN   5969.0   2422.0
# 996            [10457]   6465.0   6465.0
#
#                                            description
# 0    ['setup', 'project', 'contain', 'gif', 'resour...
# 1    ['open', 'repository', 'resource', 'always', '...
# 2    ['platform', 'able', 'notify', 'people', 'reso...
# 3    ['seem', 'need', 'vcm', 'event', 'notification...
# 4    ['think', 'would', 'useful', 'set', 'repo', 'c...
# ..                                                 ...
# 992  ['fully', 'aware', 'java', 'package', 'arent',...
# 993  ['press', 'ctrl', 'shift', 'progress', 'inform...
# 994  ['create', 'project', 'nondefault', 'location'...
# 995  ['use', 'findreplace', 'dialog', 'text', 'edit...
# 996  ['step', 'reproduce', 'create', 'class', 'publ...
#
# [997 rows x 7 columns]

# %%
def get_corpus(data):
    corpus = []
    for str_list in data['description'].tolist():
        word_lst = ast.literal_eval(str_list)
        corpus.append(word_lst)
    return corpus

# %% [markdown]
# ## Train Word2Vec model

# %%
vec_size = 300
full_corpus = get_corpus(data)
# random
model_random = Word2Vec(full_corpus, vector_size=vec_size, min_count=0)

# %%
# pretrained
model_pretrained = Word2Vec(vector_size=vec_size, min_count=1)
model_pretrained.build_vocab(full_corpus)

# %%
pretrained = api.load("glove-wiki-gigaword-300")
tmp_file = get_tmpfile("pretrained_vectors.txt")
pretrained.save_word2vec_format(tmp_file)
init_vocab = [list(pretrained.key_to_index.keys())]

# %%
model_pretrained.build_vocab(init_vocab, update=True)
model_pretrained.wv.vectors_lockf = np.ones(len(model_pretrained.wv))
model_pretrained.wv.intersect_word2vec_format(tmp_file, binary=False, lockf=1.0)

# %%
model_pretrained.train(full_corpus, total_examples=len(full_corpus), epochs=100)
# Out:
# (5307912, 5308200)

# %%
model_pretrained.save("pretrained_word2vec")

# %%
# fine-tuned
docs = Path('docs/eclipse5.txt').read_text()
docs = ast.literal_eval(docs)
model_finetuned = Word2Vec(vector_size=vec_size, min_count=1)
model_finetuned.build_vocab([docs])
model_finetuned.build_vocab(full_corpus)

# %%
model_finetuned.build_vocab(init_vocab, update=True)
model_finetuned.wv.vectors_lockf = np.ones(len(model_finetuned.wv))
model_finetuned.wv.intersect_word2vec_format(tmp_file, binary=False, lockf=1.0)

# %%
model_finetuned.train([docs], total_examples=1, epochs=100)
model_finetuned.train(full_corpus, total_examples=len(full_corpus), epochs=100)
# Out:
# (5307941, 5308200)

# %%
model_finetuned.save('finetuned_word2vec')

# %% [markdown]
# ## Bug Duplication Search

# %%
def get_doc_embedding(doc, model):
    result = np.zeros(vec_size)
    for word in doc:
        result += model[word]
    
    return result / len(doc)

def get_reports_embeddings(model, data):
    embeddings = []
    corpus = get_corpus(data)
    for report in corpus:
        embeddings.append(get_doc_embedding(report, model))
    return embeddings

def sim(vec1, vec2):
    return np.linalg.norm(vec1 - vec2)

def find_top_duplicate(bug_descr, embeddings, model, topn=10):
    min_id = 0
    min_sim = np.inf
    doc_emb = get_doc_embedding(bug_descr, model)
    sims = []
    for report_emb in embeddings:
        sims.append(sim(report_emb, doc_emb))
    sims = np.array(sims)
    sims = sims.argsort()[1:topn]
    return sims

# %% [markdown]
# ## Evaluation of the Approach

# %%
test = pd.read_csv('csv/short_dupl2017.csv')
master = pd.read_csv('csv/short_master2017.csv')

# %%
master
# Out:
#        id resolution                                         short_desc  \
# 0       1       FIXE      ['usability', 'issue', 'external', 'editors']
# 1       2       FIXE  ['open', 'repository', 'resources', 'doesnt', ...
# 2       7       WONT  ['team', 'api', 'movecopy', 'semantics', 'pres...
# 3      10       FIXE            ['api', 'vcm', 'event', 'notification']
# 4      20       FIXE                              ['workspace', 'file']
# ..    ...        ...                                                ...
# 563  6437       FIXE                              ['timeout', 'launch']
# 564  6454       FIXE    ['option', 'show', 'package', 'hierarchically']
# 565  6455       DUPL           ['npe', 'kill', 'javaindexer', 'thread']
# 566  6457       FIXE  ['rename', 'project', 'change', 'project', 'lo...
# 567  6465       FIXE     ['code', 'assist', 'work', 'front', 'comment']
#
#               dup_list  root_id  disc_id  \
# 0                [183]      1.0      1.0
# 1    [94, 9779, 15392]      2.0      2.0
# 2              [42962]      7.0      7.0
# 3             [121067]     10.0     10.0
# 4                 [40]     20.0     20.0
# ..                 ...      ...      ...
# 563      [6919, 49659]   6437.0   6437.0
# 564     [10029, 24425]   6454.0   6454.0
# 565                NaN  15262.0   6455.0
# 566             [8445]   6457.0   6457.0
# 567            [10457]   6465.0   6465.0
#
#                                            description
# 0    ['setup', 'project', 'contain', 'gif', 'resour...
# 1    ['open', 'repository', 'resource', 'always', '...
# 2    ['platform', 'able', 'notify', 'people', 'reso...
# 3    ['seem', 'need', 'vcm', 'event', 'notification...
# 4    ['think', 'would', 'useful', 'set', 'repo', 'c...
# ..                                                 ...
# 563  ['eclipse', 'corneri', 'continue', 'experience...
# 564  ['fully', 'aware', 'java', 'package', 'arent',...
# 565  ['press', 'ctrl', 'shift', 'progress', 'inform...
# 566  ['create', 'project', 'nondefault', 'location'...
# 567  ['step', 'reproduce', 'create', 'class', 'publ...
#
# [568 rows x 7 columns]

# %%
test
# Out:
#        id resolution                                         short_desc  \
# 0      40       DUPL              ['need', 'connect', 'team', 'stream']
# 1      48       DUPL  ['make', 'sure', 'future', 'store', 'project',...
# 2      61       DUPL                      ['vcmmeta', 'show', 'change']
# 3      94       DUPL  ['repositories', 'view', 'file', 'type', 'open...
# 4      98       DUPL                                           ['need']
# ..    ...        ...                                                ...
# 424  6425       DUPL           ['motif', 'dropdown', 'inconsistencies']
# 425  6426       DUPL  ['automatic', 'version', 'number', 'contain', ...
# 426  6449       DUPL                    ['error', 'close', 'workspace']
# 427  6453       DUPL           ['npe', 'create', 'java', 'perspective']
# 428  6460       DUPL     ['find', 'dialog', 'box', 'obscure', 'result']
#
#     dup_list   root_id  disc_id  \
# 0        NaN      20.0     20.0
# 1        NaN      22.0     22.0
# 2        NaN      60.0     60.0
# 3        NaN       2.0      2.0
# 4        NaN      26.0     26.0
# ..       ...       ...      ...
# 424      NaN  193318.0   5088.0
# 425      NaN    6149.0   6149.0
# 426      NaN    5903.0   5674.0
# 427      NaN    6273.0   5925.0
# 428      NaN    5969.0   2422.0
#
#                                            description
# 0    ['would', 'like', 'able', 'connect', 'team', '...
# 1    ['project', 'reference', 'come', 'three', 'fla...
# 2    ['user', 'user', 'install', 'drop', 'declipseu...
# 3    ['browse', 'file', 'repositories', 'view', 'tr...
# 4    ['need', 'new', 'button', 'repo', 'connection'...
# ..                                                 ...
# 424  ['public', 'class', 'dropdowntest', 'public', ...
# 425  ['versioning', 'automatic', 'version', 'name',...
# 426  ['close', 'workspace', 'get', 'message', 'some...
# 427  ['upgrade', 'problems', 'lose', 'jre', 'settin...
# 428  ['use', 'findreplace', 'dialog', 'text', 'edit...
#
# [429 rows x 7 columns]

# %%
def get_recall(data, test, model):
    embeddings = get_reports_embeddings(model.wv, data)
    test_size = len(test.index)
    test_corpus = get_corpus(test)
    TP = 0.
    for ind, descr in enumerate(test_corpus):
        dupl_ids = find_top_duplicate(descr, embeddings, model.wv, topn=100)
        val = 0.
        for dupl_id in dupl_ids:
            if data.iloc[dupl_id]['disc_id'] == test.iloc[ind]['disc_id']:
                val = 1.
                break
        TP += val
    return TP / test_size

# %%
print(f"RECALL random = {get_recall(data, test, model_random)}")
print(f"RECALL pretrained = {get_recall(data, test, model_pretrained)}")
print(f"RECALL fine-tuned = {get_recall(data, test, model_finetuned)}")
# Out:
# RECALL random = 0.34032634032634035
# RECALL pretrained = 0.6153846153846154
# RECALL fine-tuned = 0.6363636363636364
